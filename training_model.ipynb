# %% [markdown]
# # 特征工程与模型建立

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import re
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 特征工程

# %%
data_path='../data/train.csv'
data=pd.read_csv(data_path)
train_data=pd.DataFrame()
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 在训练集中加入最重要的性别维度

# %%
train_data['is_female']=data['Sex']=='female'
train_data['is_female']=train_data['is_female'].astype(int)

# %% [markdown]
# 加入每个人的价格维度

# %%
train_data['mean_Fare']=data.groupby('Ticket')['Fare'].transform('mean')

# %% [markdown]
# 加入团体相关维度

# %%
train_data['SibSp']=data['SibSp']
train_data['Parch']=data['Parch']
train_data['total_relatives']=data['SibSp']+data['Parch']

# %% [markdown]
# 我们对Embarked维度做one-hot编码

# %%
train_data['Embarked_in_C']=(data['Embarked']=='C').astype(int)
train_data['Embarked_in_S']=(data['Embarked']=='S').astype(int)
train_data['Embarked_in_Q']=(data['Embarked']=='Q').astype(int)
train_data.head()
# Out:
#    is_female  mean_Fare  SibSp  Parch  total_relatives  Embarked_in_C  \
# 0          0     7.2500      1      0                1              0
# 1          1    71.2833      1      0                1              1
# 2          1     7.9250      0      0                0              0
# 3          1    53.1000      1      0                1              0
# 4          0     8.0500      0      0                0              0
#
#    Embarked_in_S  Embarked_in_Q
# 0              1              0
# 1              0              0
# 2              1              0
# 3              1              0
# 4              1              0

# %% [markdown]
# 我们对Cabin是否缺失编码,并对未缺失者提取位置信息

# %%
train_data['Cabin_isna']=data['Cabin'].isna()
train_data['Cabin_isna']=train_data['Cabin_isna'].astype(int)

# %% [markdown]
# 提取船舱位置维度

# %%
data['Cabin_type']=data['Cabin'].str[0]
data[['Cabin','Cabin_type']].head(15)
value={'A':1,'G':2,'C':3,'F':4,'B':5,'E':6,'D':7}#按照生存率由低到高目标编码
def TypeToValue(row):
    tmp=row['Cabin_type']
    if tmp in value:
        return value[tmp]
    else :
        return 0
train_data['Cabin_value']=data.apply(TypeToValue,axis=1)

# %% [markdown]
# 名字中带有master的小男孩是男性中生存率最高的部分，将它提取至训练集中

# %%
data['name_title']=data['Name'].str.extract(r',\s*([^\.]+)\.',expand=False)#提取名字中的称谓
standard={'Mrs','Miss','Mr','Master'}
def standard_title(row):
    tmp = row['name_title']
    if tmp in ['Ms', 'Mlle']:       # 法语 Mademoiselle
        return 'Miss'
    elif tmp == 'Mme':              # 法语 Madame
        return 'Mrs'
    elif tmp not in standard:       # 其他少见称谓
        return 'Rare'
    else:
        return tmp
data['name_title'] = data.apply(standard_title, axis=1)
train_data['is_Mrs']=(data['name_title']=='Mrs').astype(int)
train_data['is_Mr']=(data['name_title']=='Mr').astype(int)
train_data['is_Miss']=(data['name_title']=='Miss').astype(int)
train_data['is_Master']=(data['name_title']=='Master').astype(int)
train_data['is_Rare']=(data['name_title']=='Rare').astype(int)

# %% [markdown]
# 我们将小于两岁的婴儿单独编码，他们是生存率最高的群体

# %%
train_data['is_baby']=(data['Age']<2).astype(int)

# %% [markdown]
# 加入舱位等级维度

# %%
train_data['Pclass']=data['Pclass']

# %% [markdown]
# 进而创建cabin是否缺失与舱位等级交互维度

# %%
train_data['Cabin_Pclass']=((train_data['Cabin_isna']==0 ) & (train_data['Pclass']==1)).astype(int)

# %% [markdown]
# 加入高级票维度

# %%
better_feature=r'^(?:PC|C(?:\.?A\.?)?|P\.?P\.?(?!/)|P/PP|SC(?:/PARIS|/AH)?)\b'#读取高级票特征
train_data['is_senior_ticket']=(data['Ticket'].str.contains(better_feature,regex=True,na=False)).astype(int)

# %% [markdown]
# 加入几乎必死维度

# %%
train_data['almost_die']=((data['Fare']==0)|(data['Ticket'].str.contains(r'LINE',regex=True,na=False))).astype(int)

# %% [markdown]
# 年龄缺失的生存率相对较低，加入训练集

# %%
train_data['Age_isna']=(data['Age'].isna()).astype(int)

# %% [markdown]
# 将年龄缺失与三等舱的强相关性编入训练集

# %%
train_data['naAge_Pclass']=((train_data['Pclass']==3)&(train_data['Age_isna']==1)).astype(int)

# %% [markdown]
# 将年龄填补缺失值后加入训练集

# %%
train_data['Age'] = data['Age'].fillna(data['Age'].median())

# %% [markdown]
# 创建女性-年龄-舱位交互特征

# %%
train_data['Age_Sex_Pclass'] = train_data['Age'] * (train_data['is_female'] == 1).astype(int) * train_data['Pclass']

# %% [markdown]
# 创建男性-一等舱交互特征

# %%
train_data['male-1pclass']=((train_data['is_female']==0)&(train_data['Pclass']==1)).astype(int)

# %% [markdown]
# 创建女性-一二等舱交互特征

# %%
train_data['female-12pclass']=((train_data['is_female']==1)&(train_data['Pclass']==1)&(train_data['Pclass']==2)).astype(int)

# %%
print(train_data.columns.tolist())
# Out:
# ['is_female', 'mean_Fare', 'SibSp', 'Parch', 'total_relatives', 'Embarked_in_C', 'Embarked_in_S', 'Embarked_in_Q', 'Cabin_isna', 'Cabin_value', 'is_Mrs', 'is_Mr', 'is_Miss', 'is_Master', 'is_Rare', 'is_baby', 'Pclass', 'Cabin_Pclass', 'is_senior_ticket', 'almost_die', 'Age_isna', 'naAge_Pclass', 'Age', 'Age_Sex_Pclass', 'male-1pclass', 'female-12pclass']

# %% [markdown]
# ## 验证模型

# %%
y_train=data['Survived']
rf = RandomForestClassifier(random_state=42)

# 定义参数网格
param_grid = {
    'n_estimators': [100, 200, 300, 500],
    'max_depth': [5, 7, 9, 11, None],
    'min_samples_leaf': [1, 2, 4, 6],
    'max_features': ['sqrt', 'log2'],
    'bootstrap': [True]
}

# 用 5 折交叉验证搜索
cv = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

grid = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    cv=cv,
    scoring='accuracy',   # 改成更直观的指标
    n_jobs=-1,
    verbose=2
)

grid.fit(train_data, y_train)

print("最佳参数:", grid.best_params_)
print("最佳平均准确率:", grid.best_score_)
# Out:
# Fitting 5 folds for each of 160 candidates, totalling 800 fits
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=100; total time=   0.2s[CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=100; total time=   0.2s
#
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=100; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=300; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=200; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=500; total time=   0.8s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=1, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=200; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=200; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=200; total time=   0.3s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=4, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   0.8s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   0.8s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=5, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=1, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=500; total time=   0.8s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=7, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s[CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.7s
#
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=9, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=9, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# ...
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   1.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=11, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=1, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=4, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=sqrt, min_samples_leaf=6, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=1, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=100; total time=   0.3s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=200; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=200; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=300; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=500; total time=   1.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=300; total time=   0.8s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=2, n_estimators=500; total time=   1.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=300; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=100; total time=   0.2s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=200; total time=   0.4s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=500; total time=   1.1s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=500; total time=   1.0s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=4, n_estimators=500; total time=   0.9s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=300; total time=   0.5s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   0.7s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   0.6s
# [CV] END bootstrap=True, max_depth=None, max_features=log2, min_samples_leaf=6, n_estimators=500; total time=   0.6s
# 最佳参数: {'bootstrap': True, 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 1, 'n_estimators': 100}
# 最佳平均准确率: 0.8417425145941874

# %% [markdown]
# ## 结果集生成

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'bootstrap': True, 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 1, 'n_estimators': 100}
# 0.8417425145941874

# %% [markdown]
# {'bootstrap': True, 'max_depth': 7, 'max_features': 'log2', 'min_samples_leaf': 1, 'n_estimators': 100},这是这个模型的最好参数

# %%
best_model=grid.best_estimator_
best_model.fit(train_data,y_train)
# Out:
# RandomForestClassifier(max_depth=7, max_features='log2', random_state=42)

# %% [markdown]
# 导入测试集

# %%
path='../data/test.csv'
test_data=pd.read_csv(path)

# %% [markdown]
# 生成特征模块

# %%
def TypeToValue(row):
    tmp=row['Cabin_type']
    if tmp in value:
        return value[tmp]
    else :
        return 0
def standard_title(row):
    tmp = row['name_title']
    if tmp in ['Ms', 'Mlle']:       # 法语 Mademoiselle
        return 'Miss'
    elif tmp == 'Mme':              # 法语 Madame
        return 'Mrs'
    elif tmp not in standard:       # 其他少见称谓
        return 'Rare'
    else:
        return tmp
value={'A':1,'G':2,'C':3,'F':4,'B':5,'E':6,'D':7}#按照生存率由低到高目标编码
standard={'Mrs','Miss','Mr','Master'}
def feature_engine(data):
    train_data=pd.DataFrame()
    train_data['is_female']=data['Sex']=='female'
    train_data['is_female']=train_data['is_female'].astype(int)
    train_data['mean_Fare']=data.groupby('Ticket')['Fare'].transform('mean')
    train_data['SibSp']=data['SibSp']
    train_data['Parch']=data['Parch']
    train_data['total_relatives']=data['SibSp']+data['Parch']
    train_data['Embarked_in_C']=(data['Embarked']=='C').astype(int)
    train_data['Embarked_in_S']=(data['Embarked']=='S').astype(int)
    train_data['Embarked_in_Q']=(data['Embarked']=='Q').astype(int)
    train_data['Cabin_isna']=data['Cabin'].isna()
    train_data['Cabin_isna']=train_data['Cabin_isna'].astype(int)
    data['Cabin_type']=data['Cabin'].str[0]
    data[['Cabin','Cabin_type']].head(15)
    train_data['Cabin_value']=data.apply(TypeToValue,axis=1)
    data['name_title']=data['Name'].str.extract(r',\s*([^\.]+)\.',expand=False)#提取名字中的称谓
    data['name_title'] = data.apply(standard_title, axis=1)
    train_data['is_Mrs']=(data['name_title']=='Mrs').astype(int)
    train_data['is_Mr']=(data['name_title']=='Mr').astype(int)
    train_data['is_Miss']=(data['name_title']=='Miss').astype(int)
    train_data['is_Master']=(data['name_title']=='Master').astype(int)
    train_data['is_Rare']=(data['name_title']=='Rare').astype(int)
    train_data['is_baby']=(data['Age']<2).astype(int)
    train_data['Pclass']=data['Pclass']
    train_data['Cabin_Pclass']=((train_data['Cabin_isna']==0 ) & (train_data['Pclass']==1)).astype(int)
    better_feature=r'^(?:PC|C(?:\.?A\.?)?|P\.?P\.?(?!/)|P/PP|SC(?:/PARIS|/AH)?)\b'#读取高级票特征
    train_data['is_senior_ticket']=(data['Ticket'].str.contains(better_feature,regex=True,na=False)).astype(int)
    train_data['almost_die']=((data['Fare']==0)|(data['Ticket'].str.contains(r'LINE',regex=True,na=False))).astype(int)
    train_data['Age_isna']=(data['Age'].isna()).astype(int)
    train_data['naAge_Pclass']=((train_data['Pclass']==3)&(train_data['Age_isna']==1)).astype(int)
    train_data['Age'] = data['Age'].fillna(data['Age'].median())
    train_data['Age_Sex_Pclass'] = train_data['Age'] * (train_data['is_female'] == 1).astype(int) * train_data['Pclass']
    train_data['male-1pclass']=((train_data['is_female']==0)&(train_data['Pclass']==1)).astype(int)
    train_data['female-12pclass']=((train_data['is_female']==1)&(train_data['Pclass']==1)&(train_data['Pclass']==2)).astype(int)
    return train_data
